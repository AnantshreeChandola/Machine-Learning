# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
music = pd.read_csv('music.csv')

# %%
music
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0      0.010200         0.833       204600   0.434
# 1              1      0.199000         0.743       326933   0.359
# 2              2      0.034400         0.838       185707   0.412
# 3              3      0.604000         0.494       199413   0.338
# 4              4      0.180000         0.678       392893   0.561
# 5              5      0.004790         0.804       251333   0.560
# 6              6      0.014500         0.739       241400   0.472
# 7              7      0.020200         0.266       349667   0.348
# 8              8      0.048100         0.603       202853   0.944
# 9              9      0.002080         0.836       226840   0.603
# 10            10      0.057200         0.525       358187   0.855
# 11            11      0.091500         0.753       324880   0.748
# 12            12      0.253000         0.603       356973   0.434
# ...

# %%
music.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# ...

# %%
music.corr()
# Out:
#                   Unnamed: 0  acousticness  danceability  duration_ms  \
# Unnamed: 0          1.000000      0.133055     -0.139615    -0.104185
# acousticness        0.133055      1.000000     -0.179894     0.071536
# danceability       -0.139615     -0.179894      1.000000     0.004695
# duration_ms        -0.104185      0.071536      0.004695     1.000000
# energy             -0.039880     -0.646319      0.038557    -0.144473
# instrumentalness   -0.104641      0.144397     -0.130561     0.305403
# key                -0.035611     -0.081037      0.022325     0.023570
# liveness           -0.039962     -0.117126     -0.132044     0.023203
# loudness            0.021935     -0.562021      0.104362    -0.273798
# mode                0.060639      0.068028     -0.047867    -0.074806
# speechiness        -0.135362     -0.099893      0.142661    -0.079562
# tempo              -0.027890     -0.127596     -0.143538    -0.076469
# ...

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
# Unnamed: 0          2017 non-null int64
# acousticness        2017 non-null float64
# danceability        2017 non-null float64
# duration_ms         2017 non-null int64
# energy              2017 non-null float64
# instrumentalness    2017 non-null float64
# key                 2017 non-null int64
# liveness            2017 non-null float64
# loudness            2017 non-null float64
# mode                2017 non-null int64
# speechiness         2017 non-null float64
# tempo               2017 non-null float64
# time_signature      2017 non-null float64
# valence             2017 non-null float64
# target              2017 non-null int64
# song_title          2017 non-null object
# artist              2017 non-null object
# dtypes: float64(10), int64(5), object(2)
# memory usage: 268.0+ KB

# %%
sns.heatmap(music.corr(),vmin=0,vmax=1)

# %%
sns.distplot(music['liveness'])

# %%
sns.distplot(music['energy'])

# %%
sns.jointplot(x='liveness',y='energy',data=music,kind='scatter')

# %%
sns.pairplot(music)

# %%
music['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df = pd.concat([music['acousticness'],music['instrumentalness'],music['target']],axis=1)

# %%
df
# Out:
#       acousticness  instrumentalness  target
# 0         0.010200          0.021900       1
# 1         0.199000          0.006110       1
# 2         0.034400          0.000234       1
# 3         0.604000          0.510000       1
# 4         0.180000          0.512000       1
# 5         0.004790          0.000000       1
# 6         0.014500          0.000007       1
# 7         0.020200          0.664000       1
# 8         0.048100          0.000000       1
# 9         0.002080          0.000000       1
# 10        0.057200          0.014300       1
# 11        0.091500          0.003480       1
# 12        0.253000          0.061900       1
# 13        0.366000          0.000000       1
# 14        0.440000          0.000000       1
# 15        0.019000          0.056300       1
# 16        0.023900          0.045100       1
# 17        0.233000          0.000490       1
# 18        0.314000          0.000000       1
# 19        0.024200          0.185000       1
# ...

# %%
sns.pairplot(df,kind='scatter')

# %%
sns.pairplot(df,kind='scatter',hue='target')

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
predictor=DecisionTreeClassifier()

# %%
x=music.drop(['target','song_title','artist'],axis=1)

# %%
y=music['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
predictor.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
p=predictor.predict(x_test)

# %%
predictor.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(p,y_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       252
#           1       1.00      1.00      1.00       253
#
# avg / total       1.00      1.00      1.00       505

# %%
print(confusion_matrix(p,y_test))
# Out:
# [[252   0]
#  [  0 253]]

# %%
predictor
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
